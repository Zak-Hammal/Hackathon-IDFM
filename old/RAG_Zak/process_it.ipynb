# %%
import os
import s3fs
import pandas as pd
import pyarrow.parquet as pa
from datetime import date
from datetime import datetime
# Create filesystem object
S3_ENDPOINT_URL = "https://" + os.environ["AWS_S3_ENDPOINT"]
fs = s3fs.S3FileSystem(client_kwargs={'endpoint_url': S3_ENDPOINT_URL})

# %%
# %pip install duckdb
import duckdb as ddb
ddb.execute("SET s3_region='fr-central';")
ddb.execute("SET s3_url_style='path';")
ddb.execute("SET s3_endpoint='minio.data-platform-self-service.net';")
ddb.execute(f"SET s3_access_key_id='{os.environ["AWS_ACCESS_KEY_ID"]}' ;") # Aussi récupérable dans les paramètres "Valeurs de Helm" du service
ddb.execute(f"SET s3_secret_access_key='{os.environ["AWS_SECRET_ACCESS_KEY"]}';")
# Out:
# Requirement already satisfied: duckdb in /opt/conda/lib/python3.12/site-packages (1.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset = fs.ls("dlb-hackathon/datasets-diffusion/historique_info_trafic")
df_it = ddb.sql("""
(select (*) from "s3://dlb-hackathon/datasets-diffusion/historique_info_trafic/historique_disruptions_2024.parquet" where messages_text like '%%fortes pluies%%' )
""").to_df()
df_it
# Out:
#           date_fichier                                    id  \
# 0  2024-08-01 23:30:00  5e2cba06-504b-11ef-a594-0a58a9feac02
# 1  2024-09-26 18:30:00  e93b4d6c-7c22-11ef-a50c-0a58a9feac02
# 2  2024-09-26 19:00:00  078563fe-7c26-11ef-a193-0a58a9feac02
# 3  2024-10-08 17:30:00  4d2bed62-8589-11ef-a193-0a58a9feac02
# 4  2024-10-09 02:00:00  7b183988-85cf-11ef-a193-0a58a9feac02
# 5  2024-10-09 09:30:00  01b7f33c-860e-11ef-a50c-0a58a9feac02
# 6  2024-10-09 09:30:00  8e3267e2-860f-11ef-a50c-0a58a9feac02
# 7  2024-10-09 09:30:00  dae669b2-860f-11ef-a193-0a58a9feac02
# 8  2024-10-09 16:30:00  db24e4f8-8588-11ef-a193-0a58a9feac02
# 9  2024-10-09 16:30:00  db45774a-8588-11ef-a193-0a58a9feac02
# 10 2024-10-09 17:00:00  db24e4f8-8588-11ef-a193-0a58a9feac02
# 11 2024-10-09 17:00:00  db45774a-8588-11ef-a193-0a58a9feac02
# 12 2024-10-09 17:00:00  4d2bed62-8589-11ef-a193-0a58a9feac02
# 13 2024-10-09 17:30:00  4d2bed62-8589-11ef-a193-0a58a9feac02
# 14 2024-10-09 19:30:00  38a04170-8662-11ef-aca5-0a58a9feac02
# 15 2024-10-10 15:00:00  bff72f8c-8705-11ef-8d26-0a58a9feac02
# 16 2024-10-10 16:30:00  83b45eb0-8713-11ef-8d26-0a58a9feac02
# 17 2024-10-11 07:00:00  da159888-878a-11ef-8d26-0a58a9feac02
# 18 2024-10-11 13:00:00  c6c30ed6-87bd-11ef-984a-0a58a9feac02
# 19 2024-10-12 07:30:00  011e8712-885a-11ef-984a-0a58a9feac02
# 20 2024-10-13 11:30:00  f31e4ce2-8944-11ef-8d26-0a58a9feac02
# 21 2024-10-17 18:30:00  00c41af4-8ca4-11ef-8d26-0a58a9feac02
# 22 2024-10-17 18:30:00  535a1248-8ca2-11ef-aca5-0a58a9feac02
# 23 2024-10-17 21:00:00  9eab9d42-8cb7-11ef-aca5-0a58a9feac02
# 24 2024-10-17 21:00:00  9e851be0-8cb7-11ef-aca5-0a58a9feac02
# 25 2024-10-17 21:00:00  9e851be0-8cb7-11ef-aca5-0a58a9feac02
# 26 2024-10-18 18:00:00  00c41af4-8ca4-11ef-8d26-0a58a9feac02
# 27 2024-10-18 18:30:00  00c41af4-8ca4-11ef-8d26-0a58a9feac02
# 20                                Actualité  perturbation  Incidents
# 21                                Actualité  perturbation  Incidents
# 22  Actualité,Actualité,Actualité,Actualité  perturbation  Incidents
# 23                      Actualité,Actualité  perturbation  Incidents
# 24                      Actualité,Actualité  perturbation  Incidents
# 25                                     None  perturbation  Incidents
# 26                                Actualité  perturbation  Incidents
# 27                                Actualité  perturbation  Incidents
#
#    severity.name     severity.effect severity.color  severity.priority  \
# 0      perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 1      perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 2      perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 3      perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 4      perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 5      perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 6      perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 7      perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 8      perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 9      perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 10     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 11     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 12     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 13     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 14     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 15     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 16     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 17     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 18     bloquante          NO_SERVICE        #FF0000                  0
# 19     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 20     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 21     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 22     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 23     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 24     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 25     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 26     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 27     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
#
#                                         messages_text  \
# 0   <p>Le trafic est ralenti sur l'ensemble de la ...
# 1   <p>La gare de Orly Ville n'est pas desservie j...
# 2   <p>La gare de Orly Ville n'est pas desservie j...
# 3   <p>09 octobre - Vigilance orange M&#233;t&#233...
# 4   <p>Les fortes pluies de la d&#233;pression KIR...
# 5   <p>Les fortes pluies de la d&#233;pression KIR...
# 6   <p>Vigilance orange M&#233;t&#233;o France &#8...
# 7   <p>Vigilance orange M&#233;t&#233;o France &#8...
# 8   <p>09 octobre - Vigilance orange M&#233;t&#233...
# 9   <p>09 octobre - Vigilance orange M&#233;t&#233...
# 10  <p>09 octobre - Vigilance orange M&#233;t&#233...
# 11  <p>09 octobre - Vigilance orange M&#233;t&#233...
# 12  <p>09 octobre - Vigilance orange M&#233;t&#233...
# 13  <p>09 octobre - Vigilance orange M&#233;t&#233...
# 14  <p>La gare de Stains La Cerisaie n'est pas des...
# 15  <p>Le trafic est perturb&#233; entre Paris Sai...
# 16  <p>Le trafic est perturb&#233; entre Paris Sai...
# 17  <p>Le trafic est perturb&#233; entre Paris Sai...
# 18  <p>Le trafic est interrompu entre Plaisir Grig...
# 19  <p>Le trafic est ralenti de Plaisir Grignon ve...
# 20  <p>Le trafic est ralenti de Plaisir Grignon ve...
# 21  <p>17 et 18 octobre - Vigilance orange M&#233;...
# 22  <p>Le trafic est fortement ralenti entre Paris...
# 23  <p>Le trafic est fortement ralenti entre Paris...
# 24  <p>Le trafic est fortement ralenti entre Paris...
# 25  <p>Le trafic est fortement ralenti entre Paris...
# 26  <p>17 et 18 octobre - Vigilance orange M&#233;...
# 27  <p>17 et 18 octobre - Vigilance orange M&#233;...
#
#    impacted_objects_pt_object_id impacted_objects_pt_object_name
# 0               line:IDFM:C01737   Transilien Train Transilien H
# 1               line:IDFM:C01727                           RER C
# 2               line:IDFM:C01727                           RER C
# 3               line:IDFM:C01731   Transilien Train Transilien R
# 4               line:IDFM:C01729                           RER E
# 5               line:IDFM:C01730   Transilien Train Transilien P
# 6               line:IDFM:C01737   Transilien Train Transilien H
# 7               line:IDFM:C01738   Transilien Train Transilien K
# 8               line:IDFM:C01728                           RER D
# 9               line:IDFM:C01731   Transilien Train Transilien R
# 10              line:IDFM:C01728                           RER D
# 11              line:IDFM:C01731   Transilien Train Transilien R
# 12              line:IDFM:C01731   Transilien Train Transilien R
# 13              line:IDFM:C01731   Transilien Train Transilien R
# 14              line:IDFM:C01999          Transilien Tramway T11
# 15              line:IDFM:C01739   Transilien Train Transilien J
# 16              line:IDFM:C01739   Transilien Train Transilien J
# 17              line:IDFM:C01739   Transilien Train Transilien J
# 18              line:IDFM:C01736   Transilien Train Transilien N
# 19              line:IDFM:C01736   Transilien Train Transilien N
# 20              line:IDFM:C01736   Transilien Train Transilien N
# 21              line:IDFM:C01731   Transilien Train Transilien R
# 22              line:IDFM:C01737   Transilien Train Transilien H
# 23              line:IDFM:C01737   Transilien Train Transilien H
# 24              line:IDFM:C01737   Transilien Train Transilien H
# 25              line:IDFM:C01737   Transilien Train Transilien H
# 26              line:IDFM:C01731   Transilien Train Transilien R
# 27              line:IDFM:C01731   Transilien Train Transilien R

# %%
df_it.columns
# Out:
# Index(['date_fichier', 'id', 'disruption_id', 'impact_id', 'period_begin',
#        'period_end', 'status', 'updated_at', 'tags', 'cause', 'category',
#        'severity.name', 'severity.effect', 'severity.color',
#        'severity.priority', 'messages_text', 'impacted_objects_pt_object_id',
#        'impacted_objects_pt_object_name'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import datetime

# Nombre d'utilisateurs à générer
n_users = 1000

# Date actuelle
today = datetime.date.today()

# Dictionnaire des lignes de transport avec leurs stations correspondantes
lines_dict = {
    "Métro 1": ["La Défense", "Champs-Elysées", "Concorde", "Bastille", "Nation"],
    "Métro 2": ["Porte Dauphine", "Charles de Gaulle - Étoile", "Anvers", "Nation"],
    "Métro 3": ["Pont de Levallois", "Saint-Lazare", "Opéra", "République", "Gambetta"],
    "Métro 4": ["Porte de Clignancourt", "Barbès", "Châtelet", "Montparnasse", "Mairie de Montrouge"],
    "Métro 5": ["Bobigny", "Gare du Nord", "République", "Bastille", "Place d'Italie"],
    "Métro 6": ["Charles de Gaulle - Étoile", "Trocadéro", "Montparnasse", "Nation"],
    "Métro 7": ["La Courneuve", "Gare de l'Est", "Opéra", "Place d'Italie", "Villejuif"],
    "Métro 8": ["Balard", "Invalides", "Opéra", "Bastille", "Créteil"],
    "Métro 9": ["Pont de Sèvres", "Trocadéro", "Chaussée d'Antin", "République", "Mairie de Montreuil"],
    "Métro 10": ["Boulogne", "La Motte-Picquet", "Odéon", "Gare d'Austerlitz"],
    "RER A": ["La Défense", "Charles de Gaulle - Étoile", "Châtelet", "Nation", "Marne-la-Vallée"],
    "RER B": ["Aéroport CDG", "Gare du Nord", "Châtelet", "Denfert-Rochereau", "Robinson"],
    "RER C": ["Versailles", "Invalides", "Musée d'Orsay", "Gare d'Austerlitz"],
    "Bus 38": ["Gare du Nord", "Châtelet", "Luxembourg", "Porte d'Orléans"],
    "Bus 72": ["Parc de Saint-Cloud", "Trocadéro", "Hôtel de Ville"]
}

# Centres d'intérêts disponibles
interests = ["Voyages", "Sport", "Musique", "Lecture", "Cuisine", "Cinéma", "Jeux vidéo", "Art et artisanat", "Randonnée et nature", "Technologie et gadgets"]

# Probabilités pour les centres d'intérêts
interests_prob = [0.2, 0.15, 0.15, 0.1, 0.1, 0.1, 0.075, 0.05, 0.05, 0.025]

# Génération des trajets avec correspondance entre lignes et stations
def generate_trips():
    trips = []
    for _ in range(2):  # Toujours deux trajets favoris
        line = np.random.choice(list(lines_dict.keys()))
        stations = lines_dict[line]
        start, end = np.random.choice(stations, 2, replace=False)
        time = f"{np.random.randint(5, 23)}:{np.random.choice([0, 30]):02d}"
        trips.append([start, end, line, time])
    return trips


def generate_ticket_info():
    types = ["Navigo Mois", "Navigo Semaine", "Ticket t+"]
    type_abo = np.random.choice(types)

    if type_abo == "Navigo Mois":
        # Date de fin le 1er jour du mois suivant
        year = today.year
        month = today.month + 1 if today.month < 12 else 1
        year += 1 if today.month == 12 else 0
        end_date = datetime.date(year, month, 1).isoformat()
        tickets_left = None
    elif type_abo == "Navigo Semaine":
        # Date de fin le prochain lundi après la date actuelle
        days_until_monday = (7 - today.weekday()) % 7
        end_date = (today + datetime.timedelta(days=days_until_monday)).isoformat()
        tickets_left = None
    elif type_abo == "Ticket t+":
        # Nombre de billets restants entre 0 et 4 majoritairement
        tickets_left = np.random.choice([0, 1, 2, 3, 4], p=[0.4, 0.2, 0.2, 0.1, 0.1])
        end_date = None  # Pas de date de fin pour les tickets simples

    return type_abo, end_date, tickets_left


# Génération des lieux favoris dans Paris (coordonnées aléatoires à Paris)
def generate_favorite_places():
    # Paris est approximativement compris entre 48.81°N - 48.90°N et 2.25°E - 2.42°E
    places = []
    for _ in range(2):  # Toujours deux lieux favoris
        latitude = np.random.uniform(48.81, 48.90)  # Génération de la latitude dans Paris
        longitude = np.random.uniform(2.25, 2.42)   # Génération de la longitude dans Paris
        places.append([latitude, longitude])
    return places

# Génération des centres d'intérêts
def generate_interests():
    return np.random.choice(interests, 2, replace=False, p=interests_prob).tolist()

# Génération des kilomètres de marche en utilisant une distribution normale
def generate_km_walked():
    mean = np.random.choice([30, 80, 120], p=[0.3, 0.4, 0.3])  # Trois groupes principaux : faible, moyen, élevé
    return np.clip(np.random.normal(mean, 15), 5, 200)  # Limiter les valeurs dans un intervalle réaliste

# Génération des PMR (5% des utilisateurs)
def generate_pmr():
    return np.random.choice([True, False], p=[0.05, 0.95])

# Génération de l'intérêt pour les événements (note de 1 à 5)
def generate_event_interest():
    return np.random.randint(1, 6)

# Création des données fictives
data = {
    "user_id": range(1, n_users + 1),
    "trajets": [generate_trips() for _ in range(n_users)],
    "billettique_type": [],
    "billettique_end_date": [],
    "billettique_tickets_left": [],
    "centres d'intérêts": [generate_interests() for _ in range(n_users)],
    "lieux favoris": [generate_favorite_places() for _ in range(n_users)],
    "km de marche dans les 90 derniers jours": [generate_km_walked() for _ in range(n_users)],
    "PMR": [generate_pmr() for _ in range(n_users)],
    "intérêt événements": [generate_event_interest() for _ in range(n_users)]
}

# Génération des abonnements ou tickets pour chaque utilisateur
for _ in range(n_users):
    type_abo, end_date, tickets_left = generate_ticket_info()
    data["billettique_type"].append(type_abo)
    data["billettique_end_date"].append(end_date)
    data["billettique_tickets_left"].append(tickets_left)

# Création d'un DataFrame
df = pd.DataFrame(data)

# Affichage des premières lignes
df.head(20)
# Out:
#     user_id                                            trajets  \
# 0         1  [[République, Opéra, Métro 3, 7:00], [Trocadér...
# 1         2  [[Parc de Saint-Cloud, Hôtel de Ville, Bus 72,...
# 2         3  [[Pont de Levallois, Gambetta, Métro 3, 10:00]...
# 3         4  [[Anvers, Charles de Gaulle - Étoile, Métro 2,...
# 4         5  [[Barbès, Porte de Clignancourt, Métro 4, 16:3...
# 5         6  [[Pont de Sèvres, Chaussée d'Antin, Métro 9, 2...
# 6         7  [[Porte Dauphine, Charles de Gaulle - Étoile, ...
# 7         8  [[Trocadéro, Hôtel de Ville, Bus 72, 8:00], [M...
# 8         9  [[Balard, Bastille, Métro 8, 8:30], [Boulogne,...
# 9        10  [[Mairie de Montrouge, Montparnasse, Métro 4, ...
# 10       11  [[Trocadéro, Hôtel de Ville, Bus 72, 13:00], [...
# 11       12  [[Hôtel de Ville, Parc de Saint-Cloud, Bus 72,...
# 12       13  [[Charles de Gaulle - Étoile, Porte Dauphine, ...
# 13       14  [[Luxembourg, Gare du Nord, Bus 38, 20:30], [G...
# 14       15  [[Trocadéro, Nation, Métro 6, 9:30], [Républiq...
# 15       16  [[Boulogne, La Motte-Picquet, Métro 10, 8:30],...
# 16       17  [[Charles de Gaulle - Étoile, Montparnasse, Mé...
# 17       18  [[Boulogne, Odéon, Métro 10, 7:30], [Balard, B...
# 18       19  [[Chaussée d'Antin, Pont de Sèvres, Métro 9, 1...
# 19       20  [[Denfert-Rochereau, Aéroport CDG, RER B, 9:30...
#
#    billettique_type billettique_end_date  billettique_tickets_left  \
# 0       Navigo Mois           2024-12-01                       NaN
# 1    Navigo Semaine           2024-11-25                       NaN
# 2    Navigo Semaine           2024-11-25                       NaN
# 3    Navigo Semaine           2024-11-25                       NaN
# 4    Navigo Semaine           2024-11-25                       NaN
# 5         Ticket t+                 None                       1.0
# 6       Navigo Mois           2024-12-01                       NaN
# 7    Navigo Semaine           2024-11-25                       NaN
# 8         Ticket t+                 None                       2.0
# 9         Ticket t+                 None                       4.0
# 10   Navigo Semaine           2024-11-25                       NaN
# 11        Ticket t+                 None                       0.0
# 12   Navigo Semaine           2024-11-25                       NaN
# 13      Navigo Mois           2024-12-01                       NaN
# 14   Navigo Semaine           2024-11-25                       NaN
# 15   Navigo Semaine           2024-11-25                       NaN
# 16   Navigo Semaine           2024-11-25                       NaN
# 17   Navigo Semaine           2024-11-25                       NaN
# 18      Navigo Mois           2024-12-01                       NaN
# 19        Ticket t+                 None                       0.0
#
#                  centres d'intérêts  \
# 0                [Lecture, Cuisine]
# 1       [Art et artisanat, Voyages]
# 2             [Jeux vidéo, Musique]
# 3                [Lecture, Cuisine]
# 4    [Randonnée et nature, Voyages]
# 5                [Voyages, Lecture]
# 6              [Cinéma, Jeux vidéo]
# 7             [Musique, Jeux vidéo]
# 8      [Randonnée et nature, Sport]
# 9             [Jeux vidéo, Musique]
# 10               [Lecture, Musique]
# 11  [Sport, Technologie et gadgets]
# 12                [Musique, Cinéma]
# 13   [Jeux vidéo, Art et artisanat]
# 14               [Voyages, Musique]
# 15               [Cuisine, Voyages]
# 16               [Musique, Voyages]
# 17                 [Musique, Sport]
# 18                 [Lecture, Sport]
# 19                [Lecture, Cinéma]
#
#                                         lieux favoris  \
# 0   [[48.818438533158364, 2.3536142237571136], [48...
# 1   [[48.8254745705916, 2.4141416318235827], [48.8...
# 2   [[48.81547759466018, 2.31507472262028], [48.84...
# 3   [[48.86263884185368, 2.4108231116610632], [48....
# 4   [[48.87617699971363, 2.3810478039553247], [48....
# 5   [[48.83587288474304, 2.3504154174884775], [48....
# 6   [[48.87089106622149, 2.3220693721551453], [48....
# 7   [[48.880704626192454, 2.253494122834162], [48....
# 8   [[48.89531771308121, 2.35132425600378], [48.87...
# 9   [[48.81402661890151, 2.401975316410092], [48.8...
# 10  [[48.83879749156181, 2.3262902535517545], [48....
# 11  [[48.86649394485144, 2.3648082592679907], [48....
# 12  [[48.81801864056774, 2.26484405089147], [48.83...
# 13  [[48.88509175850167, 2.325102940110694], [48.8...
# 14  [[48.89423860345912, 2.4192595928695617], [48....
# 15  [[48.892196974245785, 2.308818756563051], [48....
# 16  [[48.87758115726483, 2.324119363933062], [48.8...
# 17  [[48.857724981793076, 2.358687489276662], [48....
# 18  [[48.87640805036447, 2.31231399736389], [48.82...
# 19  [[48.8734914990657, 2.4146547037161223], [48.8...
#
#     km de marche dans les 90 derniers jours    PMR  intérêt événements
# 0                                 98.991072  False                   2
# 1                                118.066748  False                   3
# 2                                152.924673  False                   1
# 3                                 40.952517  False                   4
# 4                                130.288649  False                   1
# 5                                100.204578  False                   2
# 6                                109.468315  False                   5
# 7                                 91.505591  False                   5
# 8                                105.853786  False                   3
# 9                                 13.116804  False                   3
# 10                                89.357829  False                   4
# 11                               142.755334  False                   3
# 12                               105.310934  False                   3
# 13                               148.415676  False                   3
# 14                                94.250925  False                   2
# 15                               124.030626  False                   5
# 16                                74.263813  False                   4
# 17                               104.418622   True                   3
# 18                                73.139011  False                   2
# 19                                50.009226  False                   5

# %%
df["trajets"][0]
# Out:
# [['République', 'Opéra', 'Métro 3', '7:00'],
#  ['Trocadéro', 'Montparnasse', 'Métro 6', '22:30']]

# %%
def add_active_it_to_df(df_it, df):
    def find_associated_its(trajets):
        """Trouver les IT associées pour un utilisateur donné."""
        associated_its = []

        if isinstance(trajets, list):  # Vérifier que trajets est bien une liste
            for trajet in trajets:
                # Vérifier que chaque trajet est une liste avec au moins 3 éléments
                if isinstance(trajet, list) and len(trajet) > 2:
                    # it_name = trajet[2]  # Récupérer le troisième élément (ex: "RER C")
                    # Filtrer les ITs actives correspondant à it_name
                    it_name = trajet[2].strip().lower()  # Normaliser le nom de l'IT
                    # Filtrer les ITs actives en utilisant une comparaison robuste
                    matching_its = df_it[
                    df_it['impacted_objects_pt_object_name'].str.strip().str.lower() == it_name]
                    for _, it_row in matching_its.iterrows():
                        associated_its.append({
                            'id': it_row['id'],  # ID unique de la disruption
                            'it_name': it_row['impacted_objects_pt_object_name'],  # Nom de l'objet IT
                            'message': it_row['messages_text'],  # Message associé
                            'period_begin': it_row['period_begin'],  # Début de la période
                            'period_end': it_row['period_end']  # Fin de la période
                        })
        return associated_its

    df['it_associée'] = df['trajets'].apply(find_associated_its)
    
    # Retourner le DataFrame mis à jour
    return df

# %%
df = add_active_it_to_df(df_it,df)
df
# Out:
#      user_id                                            trajets  \
# 0          1  [[République, Opéra, Métro 3, 7:00], [Trocadér...
# 1          2  [[Parc de Saint-Cloud, Hôtel de Ville, Bus 72,...
# 2          3  [[Pont de Levallois, Gambetta, Métro 3, 10:00]...
# 3          4  [[Anvers, Charles de Gaulle - Étoile, Métro 2,...
# 4          5  [[Barbès, Porte de Clignancourt, Métro 4, 16:3...
# ..       ...                                                ...
# 995      996  [[Bastille, Concorde, Métro 1, 17:30], [Porte ...
# 996      997  [[Opéra, Gare de l'Est, Métro 7, 11:00], [Char...
# 997      998  [[Hôtel de Ville, Trocadéro, Bus 72, 15:00], [...
# 998      999  [[Châtelet, Robinson, RER B, 18:30], [Hôtel de...
# 999     1000  [[Châtelet, Luxembourg, Bus 38, 19:00], [Gare ...
#
#     billettique_type billettique_end_date  billettique_tickets_left  \
# 0        Navigo Mois           2024-12-01                       NaN
# 1     Navigo Semaine           2024-11-25                       NaN
# 2     Navigo Semaine           2024-11-25                       NaN
# 3     Navigo Semaine           2024-11-25                       NaN
# 4     Navigo Semaine           2024-11-25                       NaN
# ..               ...                  ...                       ...
# 995        Ticket t+                 None                       1.0
# 996      Navigo Mois           2024-12-01                       NaN
# 997        Ticket t+                 None                       0.0
# 998      Navigo Mois           2024-12-01                       NaN
# 999        Ticket t+                 None                       0.0
#
#                  centres d'intérêts  \
# 0                [Lecture, Cuisine]
# 1       [Art et artisanat, Voyages]
# 2             [Jeux vidéo, Musique]
# 3                [Lecture, Cuisine]
# 4    [Randonnée et nature, Voyages]
# ..                              ...
# 995              [Voyages, Cuisine]
# 996                [Sport, Cuisine]
# 997    [Randonnée et nature, Sport]
# 998              [Cuisine, Musique]
# 999                [Musique, Sport]
#
#                                          lieux favoris  \
# 0    [[48.818438533158364, 2.3536142237571136], [48...
# 1    [[48.8254745705916, 2.4141416318235827], [48.8...
# 2    [[48.81547759466018, 2.31507472262028], [48.84...
# 3    [[48.86263884185368, 2.4108231116610632], [48....
# 4    [[48.87617699971363, 2.3810478039553247], [48....
# ..                                                 ...
# 995  [[48.86589201655439, 2.3805227931500217], [48....
# 996  [[48.81081290355639, 2.408016847591765], [48.8...
# 997  [[48.87706040434309, 2.371052746675446], [48.8...
# 998  [[48.87609167928193, 2.313856437285394], [48.8...
# 999  [[48.851152812740466, 2.2605596234076724], [48...
#
#      km de marche dans les 90 derniers jours    PMR  intérêt événements  \
# 0                                  98.991072  False                   2
# 1                                 118.066748  False                   3
# 2                                 152.924673  False                   1
# 3                                  40.952517  False                   4
# 4                                 130.288649  False                   1
# ..                                       ...    ...                 ...
# 995                                34.000996  False                   4
# 996                                39.744532  False                   4
# 997                                54.582744  False                   1
# 998                                26.336683  False                   2
# 999                               134.108887  False                   2
#
#     it_associée
# 0            []
# 1            []
# 2            []
# 3            []
# 4            []
# ..          ...
# 995          []
# 996          []
# 997          []
# 998          []
# 999          []
#
# [1000 rows x 11 columns]

# %%
df.to_csv("user_it.csv")

# %%
df_it
# Out:
#           date_fichier                                    id  \
# 0  2024-08-01 23:30:00  5e2cba06-504b-11ef-a594-0a58a9feac02
# 1  2024-09-26 18:30:00  e93b4d6c-7c22-11ef-a50c-0a58a9feac02
# 2  2024-09-26 19:00:00  078563fe-7c26-11ef-a193-0a58a9feac02
# 3  2024-10-08 17:30:00  4d2bed62-8589-11ef-a193-0a58a9feac02
#
perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 20     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 21     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 22     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 23     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 24     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 25     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 26     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
# 27     perturbée  SIGNIFICANT_DELAYS        #EF662F                 30
#
#                                         messages_text  \
# 0   <p>Le trafic est ralenti sur l'ensemble de la ...
# 1   <p>La gare de Orly Ville n'est pas desservie j...
# 2   <p>La gare de Orly Ville n'est pas desservie j...
# 3   <p>09 octobre - Vigilance orange M&#233;t&#233...
# 4   <p>Les fortes pluies de la d&#233;pression KIR...
# 5   <p>Les fortes pluies de la d&#233;pression KIR...
# 6   <p>Vigilance orange M&#233;t&#233;o France &#8...
# 7   <p>Vigilance orange M&#233;t&#233;o France &#8...
# 8   <p>09 octobre - Vigilance orange M&#233;t&#233...
# 9   <p>09 octobre - Vigilance orange M&#233;t&#233...
# 10  <p>09 octobre - Vigilance orange M&#233;t&#233...
# 11  <p>09 octobre - Vigilance orange M&#233;t&#233...
# 12  <p>09 octobre - Vigilance orange M&#233;t&#233...
# 13  <p>09 octobre - Vigilance orange M&#233;t&#233...
# 14  <p>La gare de Stains La Cerisaie n'est pas des...
# 15  <p>Le trafic est perturb&#233; entre Paris Sai...
# 16  <p>Le trafic est perturb&#233; entre Paris Sai...
# 17  <p>Le trafic est perturb&#233; entre Paris Sai...
# 18  <p>Le trafic est interrompu entre Plaisir Grig...
# 19  <p>Le trafic est ralenti de Plaisir Grignon ve...
# 20  <p>Le trafic est ralenti de Plaisir Grignon ve...
# 21  <p>17 et 18 octobre - Vigilance orange M&#233;...
# 22  <p>Le trafic est fortement ralenti entre Paris...
# 23  <p>Le trafic est fortement ralenti entre Paris...
# 24  <p>Le trafic est fortement ralenti entre Paris...
# 25  <p>Le trafic est fortement ralenti entre Paris...
# 26  <p>17 et 18 octobre - Vigilance orange M&#233;...
# 27  <p>17 et 18 octobre - Vigilance orange M&#233;...
#
#    impacted_objects_pt_object_id impacted_objects_pt_object_name
# 0               line:IDFM:C01737   Transilien Train Transilien H
# 1               line:IDFM:C01727                           RER C
# 2               line:IDFM:C01727                           RER C
# 3               line:IDFM:C01731   Transilien Train Transilien R
# 4               line:IDFM:C01729                           RER E
# 5               line:IDFM:C01730   Transilien Train Transilien P
# 6               line:IDFM:C01737   Transilien Train Transilien H
# 7               line:IDFM:C01738   Transilien Train Transilien K
# 8               line:IDFM:C01728                           RER D
# 9               line:IDFM:C01731   Transilien Train Transilien R
# 10              line:IDFM:C01728                           RER D
# 11              line:IDFM:C01731   Transilien Train Transilien R
# 12              line:IDFM:C01731   Transilien Train Transilien R
# 13              line:IDFM:C01731   Transilien Train Transilien R
# 14              line:IDFM:C01999          Transilien Tramway T11
# 15              line:IDFM:C01739   Transilien Train Transilien J
# 16              line:IDFM:C01739   Transilien Train Transilien J
# 17              line:IDFM:C01739   Transilien Train Transilien J
# 18              line:IDFM:C01736   Transilien Train Transilien N
# 19              line:IDFM:C01736   Transilien Train Transilien N
# 20              line:IDFM:C01736   Transilien Train Transilien N
# 21              line:IDFM:C01731   Transilien Train Transilien R
# 22              line:IDFM:C01737   Transilien Train Transilien H
# 23              line:IDFM:C01737   Transilien Train Transilien H
# 24              line:IDFM:C01737   Transilien Train Transilien H
# 25              line:IDFM:C01737   Transilien Train Transilien H
# 26              line:IDFM:C01731   Transilien Train Transilien R
# 27              line:IDFM:C01731   Transilien Train Transilien R
